# %%
import pandas as pd
import numpy as np
df = pd.read_excel("students.xlsx")

# %%
print(df.head())
# Out:
#    StudentID          Name     Age Gender  Score   Department AttendanceRate  \
# 0        101     Ahmed Ali      21      M   85.0  Engineering           0.92
# 1        102  Sara Mohamed      20      F   78.0      Science           0.88
# 2        103    John Smith      22      M    NaN  Engineering           0.85
# 3        104   Mona Hassan      19      F   91.0         Arts           0.95
# 4        105      Ali Reza  twenty      M   67.0      Science            0.8
#
#   Graduated
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No

# %%
print(df.tail())
# Out:
#     StudentID          Name  Age Gender  Score   Department AttendanceRate  \
# 35        136  Sara Ibrahim   20      F   79.0      Science           0.82
# 36        137     Ahmed Ali   21      M   85.0  Engineering           0.92
# 37        138    Hana Saeed   19      F   89.0         Arts           0.91
# 38        139    John Smith   22      M    NaN  Engineering           0.85
# 39        140   Invalid Row  NaN      M  100.0      Unknown            abc
#
#    Graduated
# 35        No
# 36       Yes
# 37       Yes
# 38       Yes
# 39     Maybe

# %%
print(df.shape)
# Out:
# (40, 8)

# %%
print(df.columns)
# Out:
# Index(['StudentID', 'Name', 'Age', 'Gender', 'Score', 'Department',
#        'AttendanceRate', 'Graduated'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# StudentID           int64
# Name               object
# Age                object
# Gender             object
# Score             float64
# Department         object
# AttendanceRate     object
# Graduated          object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StudentID       40 non-null     int64
#  1   Name            40 non-null     object
#  2   Age             39 non-null     object
#  3   Gender          40 non-null     object
#  4   Score           34 non-null     float64
#  5   Department      37 non-null     object
#  6   AttendanceRate  40 non-null     object
#  7   Graduated       40 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.6+ KB
# None

# %%
print(df.describe())
# Out:
#         StudentID       Score
# count   40.000000   34.000000
# mean   120.500000   83.676471
# std     11.690452    8.419748
# min    101.000000   67.000000
# 25%    110.750000   78.000000
# 50%    120.500000   85.000000
# 75%    130.250000   89.750000
# max    140.000000  100.000000

# %%
print(df.isnull().sum())
# Out:
# StudentID         0
# Name              0
# Age               1
# Gender            0
# Score             6
# Department        3
# AttendanceRate    0
# Graduated         0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0
